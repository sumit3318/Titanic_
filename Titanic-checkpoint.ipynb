# %%
# Here we only used python and some python library function 
# Here we used some library function ( data manipulation,analysis and visualization)
import pandas as pd          # we use pandas for the data clining and ma
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv("C:/Users/User/Downloads/data/Titanic-Dataset.csv") #here is path of data file
df #it will show how many data in the data file
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.size #it will show size of data
# Out:
# 10692

# %%
df.shape #it will show shape of data
# Out:
# (891, 12)

# %%
df.info() #it will give the information of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.ndim
# Out:
# 2

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_7731a_row0_col0, #T_7731a_row0_col1, #T_7731a_row0_col2, #T_7731a_row0_col3, #T_7731a_row0_col4, #T_7731a_row0_col5, #T_7731a_row0_col6, #T_7731a_row7_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7731a_row1_col0, #T_7731a_row5_col0 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_7731a_row1_col1, #T_7731a_row1_col2, #T_7731a_row1_col4, #T_7731a_row1_col5, #T_7731a_row2_col1, #T_7731a_row2_col2, #T_7731a_row2_col4, #T_7731a_row2_col5, #T_7731a_row3_col0, #T_7731a_row3_col1, #T_7731a_row3_col2, #T_7731a_row3_col3, #T_7731a_row3_col4, #T_7731a_row3_col5, #T_7731a_row3_col6, #T_7731a_row4_col1, #T_7731a_row4_col2, #T_7731a_row4_col4, #T_7731a_row4_col5, #T_7731a_row5_col1, #T_7731a_row5_col2, #T_7731a_row5_col4, #T_7731a_row5_col5, #T_7731a_row6_col1, #T_7731a_row6_col2, #T_7731a_row6_col4, #T_7731a_row6_col5, #T_7731a_row7_col1, #T_7731a_row7_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7731a_row1_col3 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_7731a_row1_col6, #T_7731a_row5_col3 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_7731a_row2_col0 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_7731a_row2_col3 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_7731a_row2_col6 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_7731a_row4_col0 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_7731a_row4_col3 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_7731a_row4_col6, #T_7731a_row7_col4 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_7731a_row5_col6 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_7731a_row6_col0 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_7731a_row6_col3 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_7731a_row6_col6 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_7731a_row7_col3 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_7731a_row7_col5 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_7731a_row7_col6 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7731a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7731a_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_7731a_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_7731a_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_7731a_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_7731a_level0_col4" class="col_heading level0 col4" >SibSp</th>
#       <th id="T_7731a_level0_col5" class="col_heading level0 col5" >Parch</th>
#       <th id="T_7731a_level0_col6" class="col_heading level0 col6" >Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7731a_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_7731a_row0_col0" class="data row0 col0" >891.000000</td>
#       <td id="T_7731a_row0_col1" class="data row0 col1" >891.000000</td>
#       <td id="T_7731a_row0_col2" class="data row0 col2" >891.000000</td>
#       <td id="T_7731a_row0_col3" class="data row0 col3" >714.000000</td>
#       <td id="T_7731a_row0_col4" class="data row0 col4" >891.000000</td>
#       <td id="T_7731a_row0_col5" class="data row0 col5" >891.000000</td>
#       <td id="T_7731a_row0_col6" class="data row0 col6" >891.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7731a_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_7731a_row1_col0" class="data row1 col0" >446.000000</td>
#       <td id="T_7731a_row1_col1" class="data row1 col1" >0.383838</td>
#       <td id="T_7731a_row1_col2" class="data row1 col2" >2.308642</td>
#       <td id="T_7731a_row1_col3" class="data row1 col3" >29.699118</td>
#       <td id="T_7731a_row1_col4" class="data row1 col4" >0.523008</td>
#       <td id="T_7731a_row1_col5" class="data row1 col5" >0.381594</td>
#       <td id="T_7731a_row1_col6" class="data row1 col6" >32.204208</td>
#     </tr>
#     <tr>
#       <th id="T_7731a_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_7731a_row2_col0" class="data row2 col0" >257.353842</td>
#       <td id="T_7731a_row2_col1" class="data row2 col1" >0.486592</td>
#       <td id="T_7731a_row2_col2" class="data row2 col2" >0.836071</td>
#       <td id="T_7731a_row2_col3" class="data row2 col3" >14.526497</td>
#       <td id="T_7731a_row2_col4" class="data row2 col4" >1.102743</td>
#       <td id="T_7731a_row2_col5" class="data row2 col5" >0.806057</td>
#       <td id="T_7731a_row2_col6" class="data row2 col6" >49.693429</td>
#     </tr>
#     <tr>
#       <th id="T_7731a_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_7731a_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_7731a_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_7731a_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_7731a_row3_col3" class="data row3 col3" >0.420000</td>
#       <td id="T_7731a_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_7731a_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_7731a_row3_col6" class="data row3 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7731a_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_7731a_row4_col0" class="data row4 col0" >223.500000</td>
#       <td id="T_7731a_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_7731a_row4_col2" class="data row4 col2" >2.000000</td>
#       <td id="T_7731a_row4_col3" class="data row4 col3" >20.125000</td>
#       <td id="T_7731a_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_7731a_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_7731a_row4_col6" class="data row4 col6" >7.910400</td>
#     </tr>
#     <tr>
#       <th id="T_7731a_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_7731a_row5_col0" class="data row5 col0" >446.000000</td>
#       <td id="T_7731a_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_7731a_row5_col2" class="data row5 col2" >3.000000</td>
#       <td id="T_7731a_row5_col3" class="data row5 col3" >28.000000</td>
#       <td id="T_7731a_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_7731a_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_7731a_row5_col6" class="data row5 col6" >14.454200</td>
#     </tr>
#     <tr>
#       <th id="T_7731a_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_7731a_row6_col0" class="data row6 col0" >668.500000</td>
#       <td id="T_7731a_row6_col1" class="data row6 col1" >1.000000</td>
#       <td id="T_7731a_row6_col2" class="data row6 col2" >3.000000</td>
#       <td id="T_7731a_row6_col3" class="data row6 col3" >38.000000</td>
#       <td id="T_7731a_row6_col4" class="data row6 col4" >1.000000</td>
#       <td id="T_7731a_row6_col5" class="data row6 col5" >0.000000</td>
#       <td id="T_7731a_row6_col6" class="data row6 col6" >31.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7731a_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_7731a_row7_col0" class="data row7 col0" >891.000000</td>
#       <td id="T_7731a_row7_col1" class="data row7 col1" >1.000000</td>
#       <td id="T_7731a_row7_col2" class="data row7 col2" >3.000000</td>
#       <td id="T_7731a_row7_col3" class="data row7 col3" >80.000000</td>
#       <td id="T_7731a_row7_col4" class="data row7 col4" >8.000000</td>
#       <td id="T_7731a_row7_col5" class="data row7 col5" >6.000000</td>
#       <td id="T_7731a_row7_col6" class="data row7 col6" >512.329200</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
ac = df['Embarked'].value_counts()

# %%
#Distribution of Passengers by Embarkation Port on the Titanic
plt.pie(ac,labels=ac.index,autopct='%2.1f%%',labeldistance=1.1,startangle=90,shadow=True);

# %%
# Age distribution by class
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Age', hue='Pclass', multiple='stack', kde=True)
plt.title('Age Distribution by Class')
plt.show()

# %%
plt.figure(figsize=(7, 6))
sns.countplot(data=df, x='Sex')
plt.title('Count Plot for Gender Column')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
colors = ['#FF9999', '#66B3FF', '#99FF99']
plt.figure(figsize=(6, 4))
sns.barplot(x='Pclass', y='Survived', data=df, errorbar=None, hue='Pclass', palette=colors, dodge=True)
plt.title('Survival Rate by Passenger Class')
plt.ylabel('Survival Rate')
plt.xlabel('Passenger Class')
plt.legend(title='Passenger Class', loc='upper right', bbox_to_anchor=(1.2, 1))
plt.show()

# %%
colors = ['#FF9999', '#66B3FF']
plt.figure(figsize=(6,4))
sns.barplot(x='Sex', y='Survived', data=df, hue='Sex', palette=colors, dodge=False)
plt.title("Survival Rate by Gender")
plt.ylabel("Survival Rate")
plt.xlabel("Gender (0 = Male, 1 = Female)")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='Pclass', hue='Survived')
plt.title("Passenger Class vs Survival")
plt.show()

# %%
print("\n🔎 5. Key Insights:")
print("5.1 Females had a much higher survival rate than males.")
print("5.2 1st Class passengers had the highest survival chances, 3rd class the lowest.")
print("5.3 Most passengers were between 20–40 years old.")
print("5.4 Passengers from Cherbourg had better survival chances compared to Southampton and Queenstown.")
print("5.5 Family size had an effect: small families (1–3 members) survived more often.")
# Out:
# 🔎 5. Key Insights:
# 5.1 Females had a much higher survival rate than males.
# 5.2 1st Class passengers had the highest survival chances, 3rd class the lowest.
# 5.3 Most passengers were between 20–40 years old.
# 5.4 Passengers from Cherbourg had better survival chances compared to Southampton and Queenstown.
# 5.5 Family size had an effect: small families (1–3 members) survived more often.
